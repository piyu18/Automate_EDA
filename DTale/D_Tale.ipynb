# %%
! pip install dtale

# %%
import pandas as pd
import dtale
import dtale.app as dtale_app

dtale_app.USE_COLAB = True 
df = pd.read_csv('train.csv')
dtale.show(df)
# Out:
# https://28hszzvwxmn-496ff2e9c6d22116-40000-colab.googleusercontent.com/dtale/main/1

# %%
from IPython.display import Image
Image('/content/dtale.gif')
